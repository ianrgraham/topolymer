# %%
import os
import glob
import pathlib

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

# %%
data_dir = pathlib.Path(os.environ["DATA_DIR"])

# %%
inputs = glob.glob(str(data_dir / "topolymer/processed/grid_densities/r-5_l-10_frac-0.20*"))

# %%
data = np.load(inputs[0], allow_pickle=True)
print(inputs[0])
# Out:
# /home/ian/Documents/Data/topolymer/processed/grid_densities/r-5_l-10_frac-0.20.npz

# %%
mesh = data["mesh"][1:]
grid = data["mesh_grid"][1:]

# %%
for mesh_frame, grid_frame in zip(mesh, grid):
    # np_grid = 
    plt.matshow(mesh_frame)
